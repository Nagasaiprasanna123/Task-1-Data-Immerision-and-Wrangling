# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("sales_transactions.csv")
df.head(20)
# Out:
#     Order_ID  Order_Date Customer_Name       City   Product     Category  \
# 0       1001  01-01-2024          Ravi  Hyderabad    Laptop  Electronics
# 1       1002  2024/01/02          Sita    Chennai     Mouse  Electronics
# 2       1003  03-01-2024          Arun  Bangalore  Keyboard  Electronics
# 3       1004  2024-01-04         Priya     Mumbai    Laptop  Electronics
# 4       1005  05-01-2024          Ravi  Hyderabad   Monitor  Electronics
# 5       1006  06-01-2024         Meena      Delhi     Chair    Furniture
# 6       1007  07-01-2024         Kiran    Chennai     Table    Furniture
# 7       1008  08-01-2024          Anil  Hyderabad    Laptop  Electronics
# 8       1009  09-01-2024          Sita    Chennai     Mouse  Electronics
# 9       1010  10-01-2024          Ravi  Hyderabad  Keyboard  Electronics
# 10      1011  11-01-2024         Priya     Mumbai     Chair    Furniture
# 11      1012  12-01-2024           NaN      Delhi    Laptop  Electronics
# 12      1013  13-01-2024          Arun  Bangalore     Mouse  Electronics
# 13      1014  14-01-2024         Meena      Delhi     Table    Furniture
# 14      1015  15-01-2024         Kiran    Chennai   Monitor  Electronics
# 15      1001  01-01-2024          Ravi  Hyderabad    Laptop  Electronics
#
#     Quantity  Unit_Price Payment_Method  Discount  Rating
# 0        1.0       55000            UPI      5000       5
# 1        2.0         500           Card         0       4
# 2        1.0        1500           Cash       100       4
# 3        1.0       55000            UPI         0       5
# 4        2.0       12000           Card      2000       3
# 5        3.0        2500            UPI         0       4
# 6        1.0        7000           Cash       500       2
# 7        1.0       55000           Card     55000       5
# 8        5.0         500            UPI         0       4
# 9        1.0        1500           Cash         0       4
# 10       2.0        2500           Card         0       3
# 11       1.0       55000            UPI         0       5
# 12       NaN         500           Card         0       4
# 13       1.0        7000           Cash      1000       2
# 14       2.0       12000            UPI         0       3
# 15       1.0       55000            UPI      5000       5

# %%
df.shape
# Out:
# (16, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        16 non-null     int64
#  1   Order_Date      16 non-null     object
#  2   Customer_Name   15 non-null     object
#  3   City            16 non-null     object
#  4   Product         16 non-null     object
#  5   Category        16 non-null     object
#  6   Quantity        15 non-null     float64
#  7   Unit_Price      16 non-null     int64
#  8   Payment_Method  16 non-null     object
#  9   Discount        16 non-null     int64
#  10  Rating          16 non-null     int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.5+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_Name     1
# City              0
# Product           0
# Category          0
# Quantity          1
# Unit_Price        0
# Payment_Method    0
# Discount          0
# Rating            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.columns
# Out:
# Index(['order_id', 'order_date', 'customer_name', 'city', 'product',
#        'category', 'quantity', 'unit_price', 'payment_method', 'discount',
#        'rating'],
#       dtype='object')

# %%
df["customer_name"] = df["customer_name"].fillna("Unknown")

# %%
df["quantity"] = df["quantity"].fillna(df["quantity"].median())

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# customer_name     0
# city              0
# product           0
# category          0
# quantity          0
# unit_price        0
# payment_method    0
# discount          0
# rating            0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df = df.drop_duplicates(subset="order_id", keep="first")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["order_date"] = pd.to_datetime(df["order_date"], errors="coerce", dayfirst=True)

# %%
df["order_size"] = pd.cut(
    df["quantity"],
    bins=[0,1,3,10],
    labels=["Small","Medium","Large"]
)

# %%
print("Missing Values:\n", df.isnull().sum())
print("\nDuplicate Rows:", df.duplicated().sum())
print("\nFinal Shape:", df.shape)
# Out:
# Missing Values:
#  order_id          0
# order_date        2
# customer_name     0
# city              0
# product           0
# category          0
# quantity          0
# unit_price        0
# payment_method    0
# discount          0
# rating            0
# order_size        0
# dtype: int64
#
# Duplicate Rows: 0
#
# Final Shape: (15, 12)

# %%
df = df.dropna(subset=["order_date"])

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# customer_name     0
# city              0
# product           0
# category          0
# quantity          0
# unit_price        0
# payment_method    0
# discount          0
# rating            0
# order_size        0
# dtype: int64

# %%
df.to_csv("final_sales_transactions.csv", index=False)
